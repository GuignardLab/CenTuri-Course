# %%
import numpy as np

# %%
A = np.load('Resources/Turing_pattern.npy')

# %%
tmp = A.astype('float16')

# %%
np.savez_compressed('test.npz', tmp)

# %%
A = np.load('test.npz')['arr_0']

# %%
A
# Out:
# array([[[ 0.549   ,  0.5513  ,  0.553   , ...,  0.7905  ,  0.7905  ,
#           0.7905  ],
#         [ 0.7153  ,  0.707   ,  0.6997  , ...,  0.789   ,  0.789   ,
#           0.789   ],
#         [ 0.6025  ,  0.6084  ,  0.613   , ...,  0.787   ,  0.787   ,
#           0.787   ],
#         ...,
#         [ 0.02011 ,  0.02634 ,  0.0327  , ..., -0.795   , -0.795   ,
#          -0.795   ],
#         [ 0.829   ,  0.815   ,  0.801   , ..., -0.7734  , -0.7734  ,
#          -0.7734  ],
#         [ 0.004696,  0.00785 ,  0.01105 , ..., -0.7607  , -0.7607  ,
#          -0.7607  ]],
#
#        [[ 0.6777  ,  0.6724  ,  0.6665  , ...,  0.764   ,  0.764   ,
#           0.764   ],
#         [ 0.27    ,  0.28    ,  0.2893  , ...,  0.7646  ,  0.7646  ,
#           0.7646  ],
#         [ 0.7354  ,  0.725   ,  0.7163  , ...,  0.766   ,  0.766   ,
#           0.766   ],
#         ...,
#         [ 0.2544  ,  0.2559  ,  0.2573  , ..., -0.801   , -0.801   ,
#          -0.801   ],
# ...
